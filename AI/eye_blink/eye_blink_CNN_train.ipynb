# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/train'
validation_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/valid'

batch_size = 50
img_size = 32

# train_datagen = ImageDataGenerator(rescale=1/255)

train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,  # 지정된 각도 범위내에서 임의로 원본 이미지를 회전
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,    #  1-수치 혹은 1+수치만큼 확대 및 축소
                                   )



validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size,img_size),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_size,img_size),                       
    batch_size=batch_size,    
    class_mode='categorical'                    
)
# Out:
# Found 54332 images belonging to 2 classes.
# Found 13585 images belonging to 2 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.applications import VGG16

np.random.seed(42)

# 모델 구축

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same',
                 activation='relu',
                 input_shape=(img_size, img_size, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())

model.add(Dense(4096, activation='relu', kernel_initializer='he_normal'))
#model.add(Dropout(0.5))
model.add(Dense(2048, activation='relu', kernel_initializer='he_normal'))
#model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu', kernel_initializer='he_normal'))

model.add(Dense(2, activation='softmax'))

model.summary()

model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 19,170,594
# Trainable params: 19,170,594
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(patience = 5) # 조기종료 콜백함수 정의

# 데이터 개수 / batch_size
steps_per_epoch = 54332 / batch_size
val_steps = 13585 / batch_size

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
# 1087/1086 [==============================] - 24s 22ms/step - loss: 0.3299 - accuracy: 0.8632 - val_loss: 0.2224 - val_accuracy: 0.9156
# Epoch 2/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.1784 - accuracy: 0.9324 - val_loss: 0.1381 - val_accuracy: 0.9501
# Epoch 3/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.1263 - accuracy: 0.9532 - val_loss: 0.1391 - val_accuracy: 0.9438
# Epoch 4/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.1004 - accuracy: 0.9639 - val_loss: 0.1051 - val_accuracy: 0.9603
# Epoch 5/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0888 - accuracy: 0.9681 - val_loss: 0.0767 - val_accuracy: 0.9729
# Epoch 6/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0749 - accuracy: 0.9731 - val_loss: 0.0701 - val_accuracy: 0.9736
# Epoch 7/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0692 - accuracy: 0.9745 - val_loss: 0.0714 - val_accuracy: 0.9740
# Epoch 8/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0636 - accuracy: 0.9758 - val_loss: 0.0600 - val_accuracy: 0.9792
# Epoch 9/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0550 - accuracy: 0.9804 - val_loss: 0.0563 - val_accuracy: 0.9803
# Epoch 10/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0505 - accuracy: 0.9817 - val_loss: 0.0515 - val_accuracy: 0.9820
# Epoch 11/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0468 - accuracy: 0.9829 - val_loss: 0.0691 - val_accuracy: 0.9770
# Epoch 12/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0444 - accuracy: 0.9836 - val_loss: 0.0507 - val_accuracy: 0.9817
# Epoch 13/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0414 - accuracy: 0.9850 - val_loss: 0.0478 - val_accuracy: 0.9828
# Epoch 14/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0386 - accuracy: 0.9860 - val_loss: 0.0454 - val_accuracy: 0.9837
# Epoch 15/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0352 - accuracy: 0.9869 - val_loss: 0.0522 - val_accuracy: 0.9806
# Epoch 16/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0350 - accuracy: 0.9872 - val_loss: 0.0690 - val_accuracy: 0.9773
# Epoch 17/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0315 - accuracy: 0.9882 - val_loss: 0.0474 - val_accuracy: 0.9830
# Epoch 18/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 0.0418 - val_accuracy: 0.9858
# Epoch 19/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0288 - accuracy: 0.9891 - val_loss: 0.0418 - val_accuracy: 0.9856
# Epoch 20/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0277 - accuracy: 0.9902 - val_loss: 0.0438 - val_accuracy: 0.9865
# Epoch 21/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0259 - accuracy: 0.9908 - val_loss: 0.0472 - val_accuracy: 0.9840
# Epoch 22/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0256 - accuracy: 0.9906 - val_loss: 0.0655 - val_accuracy: 0.9795
# Epoch 23/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0244 - accuracy: 0.9913 - val_loss: 0.0458 - val_accuracy: 0.9857
# Epoch 24/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0234 - accuracy: 0.9913 - val_loss: 0.0449 - val_accuracy: 0.9859

# %%
model.compile(optimizer=Adam(learning_rate=1e-7), loss='categorical_crossentropy',
                metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.0402 - val_accuracy: 0.9870
# Epoch 2/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0149 - accuracy: 0.9951 - val_loss: 0.0398 - val_accuracy: 0.9867
# Epoch 3/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0396 - val_accuracy: 0.9865
# Epoch 4/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0395 - val_accuracy: 0.9866
# Epoch 5/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0393 - val_accuracy: 0.9867
# Epoch 6/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0393 - val_accuracy: 0.9865
# Epoch 7/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0393 - val_accuracy: 0.9868
# Epoch 8/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0393 - val_accuracy: 0.9870
# Epoch 9/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0392 - val_accuracy: 0.9866
# Epoch 10/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0392 - val_accuracy: 0.9868
# Epoch 11/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0392 - val_accuracy: 0.9865
# Epoch 12/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.0393 - val_accuracy: 0.9865
# Epoch 13/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0393 - val_accuracy: 0.9868
# Epoch 14/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0393 - val_accuracy: 0.9867
# Epoch 15/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0393 - val_accuracy: 0.9867
# Epoch 16/100
# 1087/1086 [==============================] - 21s 19ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0393 - val_accuracy: 0.9866

# %%
model.save('C:/Users/s_csmscox/jupyterSave/eye_blink/eye_blink_CNN.h5')
